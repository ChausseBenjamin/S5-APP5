# %%
import marimo as mo
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4*np.pi, 1000)
y = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.gca()
